# %% [markdown]
# 학업 중단의 원인이

# %%
import pandas as pd

file_path = r'C:\Users\brigh\Documents\GitHub\warehouse\Data_analysis_competition\ara_data\data\중도탈락 학생 현황_학교별평균값\전처리 전\2022_대학_학교별.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#     2022년_ [중도탈락 학생 현황 (대학)] Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        NaN        NaN        NaN        NaN        NaN
# 1                        NaN        NaN        NaN        NaN        NaN
# 2                       기준연도       학교종류       설립구분         지역         상태
# 3                        NaN        NaN        NaN        NaN        NaN
# 4                       2021        대학교         사립         경남         기존
# ..                       ...        ...        ...        ...        ...
# 243                     2021       산업대학         사립         전북         기존
# 244                     2021        대학교         사립         세종         기존
# 245                     2021        대학교         사립         서울         기존
# 246                     2021        대학교         사립         경기         기존
# 247                     2021  사이버대학(대학)         사립         부산         기존
#
#        Unnamed: 5 Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...
